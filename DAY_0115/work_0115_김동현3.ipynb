# %%
import pandas as pd

# %%
filename = '../DATA/시도별 전출입 인구수.xlsx'

# %%
migrationDF = pd.read_excel(filename)

# %%
migrationDF.set_index(['전출지별', '전입지별'], inplace = True)

# %%
migrationDF.index
# Out:
# MultiIndex([('전출지별',    '전입지별'),
#             (  '전국',      '전국'),
#             (   nan,   '서울특별시'),
#             (   nan,   '부산광역시'),
#             (   nan,   '대구광역시'),
#             (   nan,   '인천광역시'),
#             (   nan,   '광주광역시'),
#             (   nan,   '대전광역시'),
#             (   nan,   '울산광역시'),
#             (   nan, '세종특별자치시'),
#             ...
#             (   nan, '세종특별자치시'),
#             (   nan,     '경기도'),
#             (   nan,     '강원도'),
#             (   nan,    '충청북도'),
#             (   nan,    '충청남도'),
#             (   nan,    '전라북도'),
#             (   nan,    '전라남도'),
#             (   nan,    '경상북도'),
#             (   nan,    '경상남도'),
#             (   nan, '제주특별자치도')],
#            names=['전출지별', '전입지별'], length=325)

# %%
# 가나다순으로 전입지별 정렬
migrationDF.sort_index(axis = 0, level = 1, inplace = True)

# %%
migrationDF
# Out:
#              1970    1971    1972    1973    1974    1975    1976    1977  \
# 전출지별 전입지별
# NaN  강원도   160959  183964  161637  241663  184385  326365  239946  246070
#      강원도     9352   12885   13561   16481   15479   27837   25927   25415
#      강원도     2090    2291    2062    2356    2291    5100    4485    4877
#      강원도        -       -       -       -       -       -       -       -
#      강원도        -       -       -       -       -       -       -       -
# ...           ...     ...     ...     ...     ...     ...     ...     ...
#      충청북도    1184    1463    1359    1181    1197    3096    1903    1781
#      충청북도    1277    1108    1205    1108    1322    3300    1933    1869
#      충청북도    5155    5340    4498    4759    4705    9232    7633    7221
#      충청북도    1346    1246    1403    1012    1208    2650    2267    2023
#      충청북도      42      59     116      82     115     185     205     128
#
# ...

# %%
migrationDF.index
# Out:
# MultiIndex([(nan,  '강원도'),
#             (nan,  '강원도'),
#             (nan,  '강원도'),
#             (nan,  '강원도'),
#             (nan,  '강원도'),
#             (nan,  '강원도'),
#             (nan,  '강원도'),
#             (nan,  '강원도'),
#             (nan,  '강원도'),
#             (nan,  '강원도'),
#             ...
#             (nan, '충청북도'),
#             (nan, '충청북도'),
#             (nan, '충청북도'),
#             (nan, '충청북도'),
#             (nan, '충청북도'),
#             (nan, '충청북도'),
#             (nan, '충청북도'),
#             (nan, '충청북도'),
#             (nan, '충청북도'),
#             (nan, '충청북도')],
#            names=['전출지별', '전입지별'], length=325)

# %%
migrationDF2 = migrationDF.xs('서울특별시', level =1)

# %%
migrationDF2
# Out:
#          1970     1971     1972     1973     1974     1975     1976     1977  \
# 전출지별
# NaN   1742813  1671705  1349333  1831858  2050392  3396662  2756510  2893403
# NaN   1232619  1158556   985945  1345508  1511726  2401970  2041724  2212213
# NaN     24263    30144    18260    24251    30284    59914    43416    42685
# NaN         -        -        -        -        -        -        -        -
# NaN         -        -        -        -        -        -        -        -
# NaN         -        -        -        -        -        -        -        -
# NaN         -        -        -        -        -        -        -        -
# NaN         -        -        -        -        -        -        -        -
# NaN         -        -        -        -        -        -        -        -
# NaN     95388    95423    90470   107177   107518   207641   144524   154021
# NaN     34563    38588    32497    40922    42649    74065    52651    52262
# ...

# %%
migrationDF2.index
# Out:
# Index([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan],
#       dtype='object', name='전출지별')

# %%
migrationDF2.index = [
 '전국',
 '서울특별시',
 '부산광역시',
 '대구광역시',
 '인천광역시',
 '광주광역시',
 '대전광역시',
 '울산광역시',
 '세종특별자치시',
 '경기도',
 '강원도',
 '충청북도',
 '충청남도',
 '전라북도',
 '전라남도',
 '경상북도',
 '경상남도',
 '제주특별자치도']

# %%
migrationDF2
# Out:
#             1970     1971     1972     1973     1974     1975     1976  \
# 전국       1742813  1671705  1349333  1831858  2050392  3396662  2756510
# 서울특별시    1232619  1158556   985945  1345508  1511726  2401970  2041724
# 부산광역시      24263    30144    18260    24251    30284    59914    43416
# 대구광역시          -        -        -        -        -        -        -
# 인천광역시          -        -        -        -        -        -        -
# 광주광역시          -        -        -        -        -        -        -
# 대전광역시          -        -        -        -        -        -        -
# 울산광역시          -        -        -        -        -        -        -
# 세종특별자치시        -        -        -        -        -        -        -
# 경기도        95388    95423    90470   107177   107518   207641   144524
# 강원도        34563    38588    32497    40922    42649    74065    52651
# 충청북도       37625    39139    29513    36260    40154    72525    50313
# ...

# %%
migrationDF2 = migrationDF2.loc['부산광역시' : ]

# %%
migrationDF2
# Out:
#           1970   1971   1972    1973    1974    1975    1976    1977    1978  \
# 부산광역시    24263  30144  18260   24251   30284   59914   43416   42685   48142
# 대구광역시        0      0      0       0       0       0       0       0       0
# 인천광역시        0      0      0       0       0       0       0       0       0
# 광주광역시        0      0      0       0       0       0       0       0       0
# 대전광역시        0      0      0       0       0       0       0       0       0
# 울산광역시        0      0      0       0       0       0       0       0       0
# 세종특별자치시      0      0      0       0       0       0       0       0       0
# 경기도      95388  95423  90470  107177  107518  207641  144524  154021  164771
# 강원도      34563  38588  32497   40922   42649   74065   52651   52262   56527
# 충청북도     37625  39139  29513   36260   40154   72525   50313   50472   70017
# 충청남도     67033  63565  40803   53320   61038  115149   81692   76119   83411
# ...

# %% [markdown]
# #### 다중 인덱스 처리

# %%
# (1)
migrationDF = pd.read_excel(filename, index_col = [0, 1])
migrationDF
# Out:
#                      1970      1971      1972      1973      1974      1975  \
# 전출지별    전입지별
# 전출지별    전입지별     이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 전국      전국        4046536   4210164   3687938   4860418   5297969   9011440
#         서울특별시     1742813   1671705   1349333   1831858   2050392   3396662
#         부산광역시      448577    389797    362202    482061    680984    805979
#         대구광역시           -         -         -         -         -         -
# ...                   ...       ...       ...       ...       ...       ...
# 제주특별자치도 전라북도          139       202       141       210       219       415
#         전라남도          631       965       857       952      1133      2808
#         경상북도          374       619       468       576       625      1123
#         경상남도          474       479       440       571      1208      1517
#         제주특별자치도      9290     12427     12210     16158     19580     34221
#
# ...

# %%
migrationDF.index
# Out:
# MultiIndex([(   '전출지별',    '전입지별'),
#             (     '전국',      '전국'),
#             (     '전국',   '서울특별시'),
#             (     '전국',   '부산광역시'),
#             (     '전국',   '대구광역시'),
#             (     '전국',   '인천광역시'),
#             (     '전국',   '광주광역시'),
#             (     '전국',   '대전광역시'),
#             (     '전국',   '울산광역시'),
#             (     '전국', '세종특별자치시'),
#             ...
#             ('제주특별자치도', '세종특별자치시'),
#             ('제주특별자치도',     '경기도'),
#             ('제주특별자치도',     '강원도'),
#             ('제주특별자치도',    '충청북도'),
#             ('제주특별자치도',    '충청남도'),
#             ('제주특별자치도',    '전라북도'),
#             ('제주특별자치도',    '전라남도'),
#             ('제주특별자치도',    '경상북도'),
#             ('제주특별자치도',    '경상남도'),
#             ('제주특별자치도', '제주특별자치도')],
#            names=['전출지별', '전입지별'], length=325)

# %%
# (2)
migrationDF = pd.read_excel(filename)
#migrationDF.fillna(method = 'ffill', inplace = True)
migrationDF = migrationDF.ffill()

migrationDF.set_index(['전출지별', '전입지별'], inplace = True)
migrationDF.index
# Out:
# MultiIndex([(   '전출지별',    '전입지별'),
#             (     '전국',      '전국'),
#             (     '전국',   '서울특별시'),
#             (     '전국',   '부산광역시'),
#             (     '전국',   '대구광역시'),
#             (     '전국',   '인천광역시'),
#             (     '전국',   '광주광역시'),
#             (     '전국',   '대전광역시'),
#             (     '전국',   '울산광역시'),
#             (     '전국', '세종특별자치시'),
#             ...
#             ('제주특별자치도', '세종특별자치시'),
#             ('제주특별자치도',     '경기도'),
#             ('제주특별자치도',     '강원도'),
#             ('제주특별자치도',    '충청북도'),
#             ('제주특별자치도',    '충청남도'),
#             ('제주특별자치도',    '전라북도'),
#             ('제주특별자치도',    '전라남도'),
#             ('제주특별자치도',    '경상북도'),
#             ('제주특별자치도',    '경상남도'),
#             ('제주특별자치도', '제주특별자치도')],
#            names=['전출지별', '전입지별'], length=325)

# %%
migrationDF2.replace('-', 0, inplace = True)
# Out:
# C:\Users\xnnly\AppData\Local\Temp\ipykernel_7912\3763789948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   migrationDF2.replace('-', 0, inplace = True)

# %%
len(migrationDF2.index)
# Out:
# 16

# %%
list(migrationDF2.index)
# Out:
# ['부산광역시',
#  '대구광역시',
#  '인천광역시',
#  '광주광역시',
#  '대전광역시',
#  '울산광역시',
#  '세종특별자치시',
#  '경기도',
#  '강원도',
#  '충청북도',
#  '충청남도',
#  '전라북도',
#  '전라남도',
#  '경상북도',
#  '경상남도',
#  '제주특별자치도']

# %%
migrationDF2
# Out:
#           1970   1971   1972    1973    1974    1975    1976    1977    1978  \
# 부산광역시    24263  30144  18260   24251   30284   59914   43416   42685   48142
# 대구광역시        0      0      0       0       0       0       0       0       0
# 인천광역시        0      0      0       0       0       0       0       0       0
# 광주광역시        0      0      0       0       0       0       0       0       0
# 대전광역시        0      0      0       0       0       0       0       0       0
# 울산광역시        0      0      0       0       0       0       0       0       0
# 세종특별자치시      0      0      0       0       0       0       0       0       0
# 경기도      95388  95423  90470  107177  107518  207641  144524  154021  164771
# 강원도      34563  38588  32497   40922   42649   74065   52651   52262   56527
# 충청북도     37625  39139  29513   36260   40154   72525   50313   50472   70017
# 충청남도     67033  63565  40803   53320   61038  115149   81692   76119   83411
# ...

# %%
migrationDF2.idxmax()
# Out:
# 1970    경기도
# 1971    경기도
# 1972    경기도
# 1973    경기도
# 1974    경기도
# 1975    경기도
# 1976    경기도
# 1977    경기도
# 1978    경기도
# 1979    경기도
# 1980    경기도
# 1981    경기도
# 1982    경기도
# 1983    경기도
# 1984    경기도
# 1985    경기도
# 1986    경기도
# 1987    경기도
# 1988    경기도
# 1989    경기도
# 1990    경기도
# 1991    경기도
# 1992    경기도
# 1993    경기도
# 1994    경기도
# 1995    경기도
# 1996    경기도
# 1997    경기도
# 1998    경기도
# 1999    경기도
# 2000    경기도
# 2001    경기도
# 2002    경기도
# 2003    경기도
# 2004    경기도
# 2005    경기도
# 2006    경기도
# 2007    경기도
# 2008    경기도
# 2009    경기도
# 2010    경기도
# 2011    경기도
# 2012    경기도
# 2013    경기도
# 2014    경기도
# 2015    경기도
# 2016    경기도
# 2017    경기도
# dtype: object

# %%
len(set(list(migrationDF2.idxmax())))
# Out:
# 1

# %%
max(migrationDF2.loc['경기도'])
# Out:
# 410274

# %%
migrationDF2.idxmin()
# Out:
# 1970      대구광역시
# 1971      대구광역시
# 1972      대구광역시
# 1973      대구광역시
# 1974      대구광역시
# 1975      대구광역시
# 1976      대구광역시
# 1977      대구광역시
# 1978      대구광역시
# 1979      대구광역시
# 1980      대구광역시
# 1981      광주광역시
# 1982      광주광역시
# 1983      광주광역시
# 1984      광주광역시
# 1985      광주광역시
# 1986      대전광역시
# 1987      대전광역시
# 1988      대전광역시
# 1989      울산광역시
# 1990      울산광역시
# 1991      울산광역시
# 1992      울산광역시
# 1993      울산광역시
# 1994      울산광역시
# 1995      울산광역시
# 1996      울산광역시
# 1997    세종특별자치시
# 1998    세종특별자치시
# 1999    세종특별자치시
# 2000    세종특별자치시
# 2001    세종특별자치시
# 2002    세종특별자치시
# 2003    세종특별자치시
# 2004    세종특별자치시
# 2005    세종특별자치시
# 2006    세종특별자치시
# 2007    세종특별자치시
# 2008    세종특별자치시
# 2009    세종특별자치시
# 2010    세종특별자치시
# 2011    세종특별자치시
# 2012    세종특별자치시
# 2013    세종특별자치시
# 2014    세종특별자치시
# 2015    세종특별자치시
# 2016    세종특별자치시
# 2017    세종특별자치시
# dtype: object

# %%
migrationDF3 = migrationDF.xs('제주특별자치도', level = 1)

# %%
migrationDF3
# Out:
#        1970   1971   1972   1973   1974   1975   1976   1977   1978   1979  \
# 전출지별
# NaN   14551  19064  19404  25845  29176  50939  36273  43287  45012  44965
# NaN    1039   1325   1617   2456   2261   3440   3623   3551   3937   4261
# NaN     766    855   1007   1229   1132   1861   1832   1875   1998   2127
# NaN       -      -      -      -      -      -      -      -      -      -
# NaN       -      -      -      -      -      -      -      -      -      -
# NaN       -      -      -      -      -      -      -      -      -      -
# NaN       -      -      -      -      -      -      -      -      -      -
# NaN       -      -      -      -      -      -      -      -      -      -
# NaN       -      -      -      -      -      -      -      -      -      -
# NaN     388    430    572    680    695   1331   1096    935   1091   1439
# NaN     245    188    269    406    283    504    376    324    333    312
# ...

# %%
migrationDF3.index
# Out:
# Index(['전국', '서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시',
#        '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도', '경상남도',
#        '제주특별자치도'],
#       dtype='object', name='전출지별')

# %%
migrationDF3.index = [
 '전국',
 '서울특별시',
 '부산광역시',
 '대구광역시',
 '인천광역시',
 '광주광역시',
 '대전광역시',
 '울산광역시',
 '세종특별자치시',
 '경기도',
 '강원도',
 '충청북도',
 '충청남도',
 '전라북도',
 '전라남도',
 '경상북도',
 '경상남도',
 '제주특별자치도']

# %%
migrationDF3
# Out:
#           1970   1971   1972   1973   1974   1975   1976   1977   1978   1979  \
# 전국       14551  19064  19404  25845  29176  50939  36273  43287  45012  44965
# 서울특별시     1039   1325   1617   2456   2261   3440   3623   3551   3937   4261
# 부산광역시      766    855   1007   1229   1132   1861   1832   1875   1998   2127
# 대구광역시        -      -      -      -      -      -      -      -      -      -
# 인천광역시        -      -      -      -      -      -      -      -      -      -
# 광주광역시        -      -      -      -      -      -      -      -      -      -
# 대전광역시        -      -      -      -      -      -      -      -      -      -
# 울산광역시        -      -      -      -      -      -      -      -      -      -
# 세종특별자치시      -      -      -      -      -      -      -      -      -      -
# 경기도        388    430    572    680    695   1331   1096    935   1091   1439
# 강원도        245    188    269    406    283    504    376    324    333    312
# ...

# %%
migrationDF3 = migrationDF3.loc['서울특별시' : '경상남도']

# %%
migrationDF3
# Out:
#          1970  1971  1972  1973  1974  1975  1976  1977  1978  1979  ...  \
# 서울특별시    1039  1325  1617  2456  2261  3440  3623  3551  3937  4261  ...
# 부산광역시     766   855  1007  1229  1132  1861  1832  1875  1998  2127  ...
# 대구광역시       -     -     -     -     -     -     -     -     -     -  ...
# 인천광역시       -     -     -     -     -     -     -     -     -     -  ...
# 광주광역시       -     -     -     -     -     -     -     -     -     -  ...
# 대전광역시       -     -     -     -     -     -     -     -     -     -  ...
# 울산광역시       -     -     -     -     -     -     -     -     -     -  ...
# 세종특별자치시     -     -     -     -     -     -     -     -     -     -  ...
# 경기도       388   430   572   680   695  1331  1096   935  1091  1439  ...
# 강원도       245   188   269   406   283   504   376   324   333   312  ...
# 충청북도       71   111   147   161   136   246   162   155   213   202  ...
# 충청남도      198   275   243   367   371   707   459   415   465   527  ...
# ...

# %%
migrationDF3.replace('-', 0, inplace = True)
# Out:
# C:\Users\xnnly\AppData\Local\Temp\ipykernel_7912\1122682167.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   migrationDF3.replace('-', 0, inplace = True)

# %%
migrationDF3.idxmax()
# Out:
# 1970     전라남도
# 1971     전라남도
# 1972     전라남도
# 1973     전라남도
# 1974     전라남도
# 1975     전라남도
# 1976    서울특별시
# 1977    서울특별시
# 1978    서울특별시
# 1979    서울특별시
# 1980    서울특별시
# 1981    서울특별시
# 1982    서울특별시
# 1983    서울특별시
# 1984    서울특별시
# 1985    서울특별시
# 1986    서울특별시
# 1987    서울특별시
# 1988    서울특별시
# 1989    서울특별시
# 1990    서울특별시
# 1991    서울특별시
# 1992    서울특별시
# 1993    서울특별시
# 1994    서울특별시
# 1995    서울특별시
# 1996    서울특별시
# 1997    서울특별시
# 1998    서울특별시
# 1999    서울특별시
# 2000    서울특별시
# 2001    서울특별시
# 2002    서울특별시
# 2003    서울특별시
# 2004    서울특별시
# 2005    서울특별시
# 2006    서울특별시
# 2007    서울특별시
# 2008    서울특별시
# 2009    서울특별시
# 2010    서울특별시
# 2011    서울특별시
# 2012    서울특별시
# 2013    서울특별시
# 2014      경기도
# 2015      경기도
# 2016      경기도
# 2017      경기도
# dtype: object

# %%
len(set(list(migrationDF3.idxmax())))
# Out:
# 3

# %%
max(migrationDF3.loc['전라남도'])
# Out:
# 5443

# %%
max(migrationDF3.loc['서울특별시'])
# Out:
# 10465

# %%
max(migrationDF3.loc['경기도'])
# Out:
# 11255
